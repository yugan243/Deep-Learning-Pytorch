# %% [markdown]
# <a href="https://colab.research.google.com/github/yugan243/Deep-Learning-Pytorch/blob/main/7_cnn_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn

# %%
x = torch.rand(1, 3, 64, 64)

# %%
x
# Out:
# tensor([[[[0.1130, 0.1334, 0.6013,  ..., 0.7571, 0.9447, 0.2349],
#           [0.1439, 0.3662, 0.2084,  ..., 0.5943, 0.4621, 0.7702],
#           [0.7054, 0.8695, 0.4028,  ..., 0.4939, 0.0583, 0.6916],
#           ...,
#           [0.9996, 0.9130, 0.6024,  ..., 0.4153, 0.0825, 0.0841],
#           [0.4100, 0.3805, 0.4187,  ..., 0.8206, 0.3883, 0.7748],
#           [0.6036, 0.0266, 0.1476,  ..., 0.1687, 0.5916, 0.8613]],
#
#          [[0.8592, 0.3840, 0.3383,  ..., 0.6838, 0.1441, 0.5831],
#           [0.5234, 0.2221, 0.8064,  ..., 0.3738, 0.8148, 0.2116],
#           [0.0274, 0.0679, 0.0926,  ..., 0.2701, 0.8484, 0.8993],
#           ...,
#           [0.1048, 0.0741, 0.3814,  ..., 0.1305, 0.2487, 0.8640],
#           [0.1836, 0.0583, 0.6188,  ..., 0.7399, 0.0236, 0.4106],
#           [0.1786, 0.7105, 0.4516,  ..., 0.7272, 0.3456, 0.2635]],
#
#          [[0.6054, 0.8615, 0.0084,  ..., 0.9396, 0.0579, 0.4395],
#           [0.2047, 0.5681, 0.4555,  ..., 0.1689, 0.1872, 0.9942],
# ...

# %%
conv_no_pad = nn.Conv2d(3, 10, kernel_size=3, padding=0)
conv_same_pad = nn.Conv2d(3, 10, kernel_size=3, padding=1)

# %%
print(conv_no_pad(x).shape)
# Out:
# torch.Size([1, 10, 62, 62])

# %%
conv_no_pad.weight.shape
# Out:
# torch.Size([10, 3, 3, 3])
